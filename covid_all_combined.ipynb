# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
import functools

# %% [markdown]
# <h2>Load the Data</h2>

# %%
fat_supply_csv = "../Resources/Fat_Supply_Quantity_Data.csv"
fat_supply_df = pd.read_csv(fat_supply_csv)
fat_supply_df.head()
# Out:
#                Country  Alcoholic Beverages  Animal Products  Animal fats  \
# 0          Afghanistan                  0.0            21.64         6.22
# 1              Albania                  0.0            32.00         3.42
# 2              Algeria                  0.0            14.42         0.90
# 3               Angola                  0.0            15.30         1.31
# 4  Antigua and Barbuda                  0.0            27.70         4.67
#
#    Aquatic Products, Other  Cereals - Excluding Beer  Eggs  Fish, Seafood  \
# 0                      0.0                      8.04  0.69           0.03
# 1                      0.0                      2.67  1.64           0.14
# 2                      0.0                      4.20  1.22           0.20
# 3                      0.0                      6.55  0.15           1.42
# 4                      0.0                      3.22  0.39           1.53
#
#    Fruits - Excluding Wine   Meat  ...  Vegetal Products  Vegetable Oils  \
# ...

# %%
kcal_supply_csv = "../Resources/Food_Supply_kcal_Data.csv"
kcal_supply_df = pd.read_csv(kcal_supply_csv)
kcal_supply_df.head()
# Out:
#                Country  Alcoholic Beverages  Animal Products  Animal fats  \
# 0          Afghanistan                 0.00             4.78         0.85
# 1              Albania                 0.91            16.09         1.06
# 2              Algeria                 0.09             6.03         0.19
# 3               Angola                 1.94             4.69         0.26
# 4  Antigua and Barbuda                 2.30            15.37         1.54
#
#    Aquatic Products, Other  Cereals - Excluding Beer  Eggs  Fish, Seafood  \
# 0                      0.0                     37.12  0.15           0.00
# 1                      0.0                     16.21  0.81           0.15
# 2                      0.0                     25.01  0.42           0.12
# 3                      0.0                     18.35  0.04           0.84
# 4                      0.0                     13.72  0.21           1.73
#
#    Fruits - Excluding Wine  Meat  ...  Vegetal Products  Vegetable Oils  \
# ...

# %%
food_quantity_csv = "../Resources/Food_Supply_Quantity_kg_Data.csv"
food_quantity_df = pd.read_csv(food_quantity_csv)
food_quantity_df.head()
# Out:
#                Country  Alcoholic Beverages  Animal fats  Animal Products  \
# 0          Afghanistan                 0.00         0.20             9.43
# 1              Albania                 1.67         0.14            18.77
# 2              Algeria                 0.27         0.03             9.63
# 3               Angola                 5.81         0.06             4.93
# 4  Antigua and Barbuda                 3.58         0.01            16.66
#
#    Aquatic Products, Other  Cereals - Excluding Beer  Eggs  Fish, Seafood  \
# 0                      0.0                     24.81  0.21           0.04
# 1                      0.0                      5.78  0.58           0.21
# 2                      0.0                     13.68  0.53           0.24
# 3                      0.0                      9.11  0.06           1.77
# 4                      0.0                      6.00  0.23           4.15
#
#    Fruits - Excluding Wine  Meat  ...  Vegetable Oils  Vegetables  \
# ...

# %%
protein_supply_csv = "../Resources/Protein_Supply_Quantity_Data.csv"
protein_supply_df = pd.read_csv(protein_supply_csv)
protein_supply_df.head()
# Out:
#                Country  Alcoholic Beverages  Animal Products  Animal fats  \
# 0          Afghanistan                 0.00             9.75         0.03
# 1              Albania                 0.18            27.75         0.07
# 2              Algeria                 0.03            13.84         0.01
# 3               Angola                 0.63            15.23         0.03
# 4  Antigua and Barbuda                 0.15            33.19         0.13
#
#    Aquatic Products, Other  Cereals - Excluding Beer  Eggs  Fish, Seafood  \
# 0                      0.0                     35.98  0.41           0.06
# 1                      0.0                     14.23  1.81           0.63
# 2                      0.0                     26.56  1.29           0.64
# 3                      0.0                     20.39  0.18           5.44
# 4                      0.0                     10.51  0.49           8.21
#
#    Fruits - Excluding Wine   Meat  ...  Vegetable Oils  Vegetables  \
# ...

# %% [markdown]
# <h2>Transform Dataframes</h2>

# %% [markdown]
# <h3>Fat Supply</h3>

# %%
## FAT SUPPY ##

# Create a filtered dataframe from specific columns
fat_supply_cols = ["Country", "Animal Products", "Cereals - Excluding Beer", "Eggs", "Fruits - Excluding Wine", \
             "Meat", "Milk - Excluding Butter", "Fish, Seafood", "Vegetables", "Obesity", "Undernourished", "Confirmed", "Deaths", "Recovered", "Population"]

# food_cols = ["Country", "Animal_Products", "Cereals", "Eggs", "Fruits", "Meat", "Milk", "Fish_Seafood", "Vegetables"]
fat_supply_transformed= fat_supply_df[fat_supply_cols].copy()

# Rename the column headers
fat_supply_transformed = fat_supply_transformed.rename(columns={'Country': 'country', 
                                                    'Animal Products':'animal_products_fat',
                                                    'Cereals - Excluding Beer':'cereals_fat',
                                                    'Eggs':'eggs_fat',
                                                    'Fruits - Excluding Wine': 'fruits_fat',
                                                    'Meat':'meat_fat',
                                                    'Milk - Excluding Butter':'milk_fat',
                                                    'Fish, Seafood': 'fish_seafood_fat', 
                                                    'Vegetables':'vegetables_fat',
                                                    'Obesity': 'obesity',
                                                    'Undernourished': 'undernourished',
                                                    'Confirmed': 'confirmed_cases',
                                                    'Deaths': 'deaths',
                                                    'Recovered': 'recovered',
                                                    'Population': 'population'})
# Clean the data by dropping duplicates and setting the index
fat_supply_transformed.drop_duplicates("country", inplace=True)
fat_supply_transformed.set_index("country", inplace=True)

fat_supply_transformed
# Out:
#                                     animal_products_fat  cereals_fat  \
# country
# Afghanistan                                       21.64         8.04
# Albania                                           32.00         2.67
# Algeria                                           14.42         4.20
# Angola                                            15.30         6.55
# Antigua and Barbuda                               27.70         3.22
# ...                                                 ...          ...
# Venezuela (Bolivarian Republic of)                16.33         2.54
# Vietnam                                           33.25         3.72
# Yemen                                             12.54        11.53
# Zambia                                             9.60        14.32
# Zimbabwe                                          10.38         9.79
#
#                                     eggs_fat  fruits_fat  meat_fat  milk_fat  \
# country
# ...

# %% [markdown]
# <h3>Food Quantity (kg)</h3>

# %%
## FOOD QUANTITY ##

# Create a filtered dataframe from specific columns
food_cols = ["Country", "Animal Products", "Cereals - Excluding Beer", "Eggs", "Fruits - Excluding Wine", \
             "Meat", "Milk - Excluding Butter", "Fish, Seafood", "Vegetables", "Obesity", "Undernourished", "Confirmed", "Deaths", "Recovered", "Population"]

# food_cols = ["Country", "Animal_Products", "Cereals", "Eggs", "Fruits", "Meat", "Milk", "Fish_Seafood", "Vegetables"]
food_transformed= food_quantity_df[food_cols].copy()

# Rename the column headers
food_transformed = food_transformed.rename(columns={'Country': 'country', 
                                                    'Animal Products':'animal_products_quantity',
                                                    'Cereals - Excluding Beer':'cereals_quantity',
                                                    'Eggs':'eggs_quantity',
                                                    'Fruits - Excluding Wine': 'fruits_quantity',
                                                    'Meat':'meat_quantity',
                                                    'Milk - Excluding Butter':'milk_quantity',
                                                    'Fish, Seafood': 'fish_seafood_quantity', 
                                                    'Vegetables':'vegetables_quantity',
                                                    'Obesity': 'obesity',
                                                    'Undernourished': 'undernourished',
                                                    'Confirmed': 'confirmed_cases',
                                                    'Deaths': 'deaths',
                                                    'Recovered': 'recovered',
                                                    'Population': 'population'})
# Clean the data by dropping duplicates and setting the index
food_transformed.drop_duplicates("country", inplace=True)
food_transformed.set_index("country", inplace=True)


food_transformed
# Out:
#                                     animal_products_quantity  \
# country
# Afghanistan                                             9.43
# Albania                                                18.77
# Algeria                                                 9.63
# Angola                                                  4.93
# Antigua and Barbuda                                    16.66
# ...                                                      ...
# Venezuela (Bolivarian Republic of)                     14.76
# Vietnam                                                 8.58
# Yemen                                                   5.79
# Zambia                                                  6.02
# Zimbabwe                                                8.15
#
#                                     cereals_quantity  eggs_quantity  \
# country
# Afghanistan                                    24.81           0.21
# Albania                                         5.78           0.58
# ...

# %% [markdown]
# <h3>KCal Supply</h3>

# %%
## KCAL SUPPY ##

# Create a filtered dataframe from specific columns
kcal_supply_cols = ["Country", "Animal Products", "Cereals - Excluding Beer", "Eggs", "Fruits - Excluding Wine", \
             "Meat", "Milk - Excluding Butter", "Fish, Seafood", "Vegetables", "Obesity", "Undernourished", "Confirmed", "Deaths", "Recovered", "Population"]

# food_cols = ["Country", "Animal_Products", "Cereals", "Eggs", "Fruits", "Meat", "Milk", "Fish_Seafood", "Vegetables"]
kcal_supply_transformed= kcal_supply_df[kcal_supply_cols].copy()

# Rename the column headers
kcal_supply_transformed = kcal_supply_transformed.rename(columns={'Country': 'country', 
                                                    'Animal Products':'animal_products_kcal',
                                                    'Cereals - Excluding Beer':'cereals_kcal',
                                                    'Eggs':'eggs_kcal',
                                                    'Fruits - Excluding Wine': 'fruits_kcal',
                                                    'Meat':'meat_kcal',
                                                    'Milk - Excluding Butter':'milk_kcal',
                                                    'Fish, Seafood': 'fish_seafood_kcal', 
                                                    'Vegetables':'vegetables_kcal',
                                                    'Obesity': 'obesity',
                                                    'Undernourished': 'undernourished',
                                                    'Confirmed': 'confirmed_cases',
                                                    'Deaths': 'deaths',
                                                    'Recovered': 'recovered',
                                                    'Population': 'population'})
# Clean the data by dropping duplicates and setting the index
kcal_supply_transformed.drop_duplicates("country", inplace=True)
kcal_supply_transformed.set_index("country", inplace=True)


kcal_supply_transformed
# Out:
#                                     animal_products_kcal  cereals_kcal  \
# country
# Afghanistan                                         4.78         37.12
# Albania                                            16.09         16.21
# Algeria                                             6.03         25.01
# Angola                                              4.69         18.35
# Antigua and Barbuda                                15.37         13.72
# ...                                                  ...           ...
# Venezuela (Bolivarian Republic of)                  7.23         21.31
# Vietnam                                            10.98         26.98
# Yemen                                               3.47         32.07
# Zambia                                              3.30         31.55
# Zimbabwe                                            3.94         29.80
#
#                                     eggs_kcal  fruits_kcal  meat_kcal  \
# country
# ...

# %% [markdown]
# <h3>Protein Supply</h3>

# %%
## PROTEIN SUPPLY ##

# Create a filtered dataframe from specific columns
protein_supply_cols = ["Country", "Animal Products", "Cereals - Excluding Beer", "Eggs", "Fruits - Excluding Wine", \
             "Meat", "Milk - Excluding Butter", "Fish, Seafood", "Vegetables", "Obesity", "Undernourished", "Confirmed", "Deaths", "Recovered", "Population"]

# food_cols = ["Country", "Animal_Products", "Cereals", "Eggs", "Fruits", "Meat", "Milk", "Fish_Seafood", "Vegetables"]
protein_supply_transformed= protein_supply_df[protein_supply_cols].copy()

# Rename the column headers
protein_supply_transformed = protein_supply_transformed.rename(columns={'Country': 'country', 
                                                    'Animal Products':'animal_products_protein',
                                                    'Cereals - Excluding Beer':'cereals_protein',
                                                    'Eggs':'eggs_protein',
                                                    'Fruits - Excluding Wine': 'fruits_protein',
                                                    'Meat':'meat_protein',
                                                    'Milk - Excluding Butter':'milk_protein',
                                                    'Fish, Seafood': 'fish_seafood_protein', 
                                                    'Vegetables':'vegetables_protein',
                                                    'Obesity': 'obesity',
                                                    'Undernourished': 'undernourished',
                                                    'Confirmed': 'confirmed_cases',
                                                    'Deaths': 'deaths',
                                                    'Recovered': 'recovered',
                                                    'Population': 'population'})
# Clean the data by dropping duplicates and setting the index
protein_supply_transformed.drop_duplicates("country", inplace=True)
protein_supply_transformed.set_index("country", inplace=True)

protein_supply_transformed
# Out:
#                                     animal_products_protein  cereals_protein  \
# country
# Afghanistan                                            9.75            35.98
# Albania                                               27.75            14.23
# Algeria                                               13.84            26.56
# Angola                                                15.23            20.39
# Antigua and Barbuda                                   33.19            10.51
# ...                                                     ...              ...
# Venezuela (Bolivarian Republic of)                    22.54            21.65
# Vietnam                                               20.45            18.52
# Yemen                                                 10.01            35.12
# Zambia                                                 9.89            28.52
# Zimbabwe                                              11.34            33.19
#
# ...

# %% [markdown]
# <h3>Merge dataframes into one</h3>

# %%
dfs = [food_transformed, kcal_supply_transformed, fat_supply_transformed, protein_supply_transformed]
nan_value = 0

##BECAUSE EACH DATASET HAS THE SAME DATA IN OBESITY, UNDERNOURISHED, CONFIRMED_CASES, DEATHS, RECOVERED, AND POPULATION THEY
##CAN BE MERGED INTO ONE LARGE DATAFRAME

covid_diet = functools.reduce(lambda left, right: pd.merge(left,right,on=['country', 'obesity', 'undernourished', 'confirmed_cases', 'deaths', 'recovered', 'population']), dfs)
covid_diet
# Out:
#                                     animal_products_quantity  \
# country
# Afghanistan                                             9.43
# Albania                                                18.77
# Algeria                                                 9.63
# Angola                                                  4.93
# Antigua and Barbuda                                    16.66
# ...                                                      ...
# Venezuela (Bolivarian Republic of)                     14.76
# Vietnam                                                 8.58
# Yemen                                                   5.79
# Zambia                                                  6.02
# Zimbabwe                                                8.15
#
#                                     cereals_quantity  eggs_quantity  \
# country
# Afghanistan                                    24.81           0.21
# Albania                                         5.78           0.58
# ...

# %% [markdown]
# <h2>Create Connection to Database</h2>

# %%
covid_diet.to_csv(r'C:\Users\Annika\dataframe.csv')

# %%
connection_string = "postgres:ilikecats@localhost:5432/food_db"
engine = create_engine(f'postgresql://{connection_string}')

# %%
engine.table_names()
# Out:
# C:\Users\Annika\anaconda2\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
#   """Entry point for launching an IPython kernel.
# ['covid_diet', 'fat_supply', 'kcal_supply', 'food_quantity', 'protein_supply']

# %% [markdown]
# <h2>Load Dataframe into SQL</h2>

# %%
covid_diet.to_sql(name='covid_diet', con=engine, if_exists='append', index=True)

# %%
fat_supply_transformed.to_sql(name='fat_supply', con=engine, if_exists='append', index=True)

# %%
food_transformed.to_sql(name='food_quantity', con=engine, if_exists='append', index=True)

# %%
kcal_supply_transformed.to_sql(name='kcal_supply', con=engine, if_exists='append', index=True)

# %%
protein_supply_transformed.to_sql(name='protein_supply', con=engine, if_exists='append', index=True)
