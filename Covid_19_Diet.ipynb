# %% [markdown]
# # Covid_19_Diet Table
# For this project, I first loaded four csv's on global diet data to create four new dataframes. I then combined all data through the pd.concat function to create one larger dataframe. I finished by loading each new dataframe into a SQL database.

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
Fat_Supply_Quantity = "Resources/Fat_Supply_Quantity_Data.csv"
Fat_Supply_Quantity_df = pd.read_csv(Fat_Supply_Quantity)
Fat_Supply_Quantity_df.head()
# Out:
#                Country  Alcoholic Beverages  Animal Products  Animal fats  \
# 0          Afghanistan                  0.0          21.6397       6.2224
# 1              Albania                  0.0          32.0002       3.4172
# 2              Algeria                  0.0          14.4175       0.8972
# 3               Angola                  0.0          15.3041       1.3130
# 4  Antigua and Barbuda                  0.0          27.7033       4.6686
#
#    Aquatic Products, Other  Cereals - Excluding Beer    Eggs  Fish, Seafood  \
# 0                      0.0                    8.0353  0.6859         0.0327
# 1                      0.0                    2.6734  1.6448         0.1445
# 2                      0.0                    4.2035  1.2171         0.2008
# 3                      0.0                    6.5545  0.1539         1.4155
# 4                      0.0                    3.2153  0.3872         1.5263
#
#    Fruits - Excluding Wine     Meat  ...  Vegetable Oils  Vegetables  Obesity  \
# 0                   0.4246   6.1244  ...         17.0831      0.3593      4.5
# 1                   0.6418   8.7428  ...          9.2443      0.6503     22.3
# 2                   0.5772   3.8961  ...         27.3606      0.5145     26.6
# 3                   0.3488  11.0268  ...         22.4638      0.1231      6.8
# 4                   1.2177  14.3202  ...         14.4436      0.2469     19.1
#
#    Undernourished  Confirmed    Deaths  Recovered    Active  Population  \
# 0            29.8   0.142134  0.006186   0.123374  0.012574  38928000.0
# 1             6.2   2.967301  0.050951   1.792636  1.123714   2838000.0
# 2             3.9   0.244897  0.006558   0.167572  0.070767  44357000.0
# 3              25   0.061687  0.001461   0.056808  0.003419  32522000.0
# 4             NaN   0.293878  0.007143   0.190816  0.095918     98000.0
#
#    Unit (all except Population)
# 0                             %
# 1                             %
# 2                             %
# 3                             %
# 4                             %
#
# [5 rows x 32 columns]

# %%
Food_Supply_Quantity = "Resources/Food_Supply_Quantity_kg_Data.csv"
Food_Supply_Quantity_df = pd.read_csv(Food_Supply_Quantity)
Food_Supply_Quantity_df.head()
# Out:
#                Country  Alcoholic Beverages  Animal fats  Animal Products  \
# 0          Afghanistan               0.0014       0.1973           9.4341
# 1              Albania               1.6719       0.1357          18.7684
# 2              Algeria               0.2711       0.0282           9.6334
# 3               Angola               5.8087       0.0560           4.9278
# 4  Antigua and Barbuda               3.5764       0.0087          16.6613
#
#    Aquatic Products, Other  Cereals - Excluding Beer    Eggs  Fish, Seafood  \
# 0                      0.0                   24.8097  0.2099         0.0350
# 1                      0.0                    5.7817  0.5815         0.2126
# 2                      0.0                   13.6816  0.5277         0.2416
# 3                      0.0                    9.1085  0.0587         1.7707
# 4                      0.0                    5.9960  0.2274         4.1489
#
#    Fruits - Excluding Wine    Meat  ...  Vegetables  Vegetal Products  \
# 0                   5.3495  1.2020  ...      6.7642           40.5645
# 1                   6.7861  1.8845  ...     11.7753           31.2304
# 2                   6.3801  1.1305  ...     11.6484           40.3651
# 3                   6.0005  2.0571  ...      2.3041           45.0722
# 4                  10.7451  5.6888  ...      5.4495           33.3233
#
#    Obesity  Undernourished  Confirmed    Deaths  Recovered    Active  \
# 0      4.5            29.8   0.142134  0.006186   0.123374  0.012574
# 1     22.3             6.2   2.967301  0.050951   1.792636  1.123714
# 2     26.6             3.9   0.244897  0.006558   0.167572  0.070767
# 3      6.8              25   0.061687  0.001461   0.056808  0.003419
# 4     19.1             NaN   0.293878  0.007143   0.190816  0.095918
#
#    Population  Unit (all except Population)
# 0  38928000.0                             %
# 1   2838000.0                             %
# 2  44357000.0                             %
# 3  32522000.0                             %
# 4     98000.0                             %
#
# [5 rows x 32 columns]

# %%
Food_Supply_Kcal = "Resources/Food_Supply_kcal_Data.csv"
Food_Supply_Kcal_df = pd.read_csv(Food_Supply_Kcal)
Food_Supply_Kcal_df.head()
# Out:
#                Country  Alcoholic Beverages  Animal Products  Animal fats  \
# 0          Afghanistan               0.0000           4.7774       0.8504
# 1              Albania               0.9120          16.0930       1.0591
# 2              Algeria               0.0896           6.0326       0.1941
# 3               Angola               1.9388           4.6927       0.2644
# 4  Antigua and Barbuda               2.3041          15.3672       1.5429
#
#    Aquatic Products, Other  Cereals - Excluding Beer    Eggs  Fish, Seafood  \
# 0                      0.0                   37.1186  0.1501         0.0000
# 1                      0.0                   16.2107  0.8091         0.1471
# 2                      0.0                   25.0112  0.4181         0.1195
# 3                      0.0                   18.3521  0.0441         0.8372
# 4                      0.0                   13.7215  0.2057         1.7280
#
#    Fruits - Excluding Wine    Meat  ...  Vegetable Oils  Vegetables  Obesity  \
# 0                   1.4757  1.2006  ...          2.3012      0.7504      4.5
# 1                   3.8982  3.8688  ...          2.8244      2.7508     22.3
# 2                   3.1805  1.2543  ...          5.7638      2.0457     26.6
# 3                   2.3133  2.9302  ...          4.2741      0.3525      6.8
# 4                   3.6824  7.0356  ...          4.6904      1.2960     19.1
#
#    Undernourished  Confirmed    Deaths  Recovered    Active  Population  \
# 0            29.8   0.142134  0.006186   0.123374  0.012574  38928000.0
# 1             6.2   2.967301  0.050951   1.792636  1.123714   2838000.0
# 2             3.9   0.244897  0.006558   0.167572  0.070767  44357000.0
# 3              25   0.061687  0.001461   0.056808  0.003419  32522000.0
# 4             NaN   0.293878  0.007143   0.190816  0.095918     98000.0
#
#    Unit (all except Population)
# 0                             %
# 1                             %
# 2                             %
# 3                             %
# 4                             %
#
# [5 rows x 32 columns]

# %%
Protein_Supply_Quantity = "Resources/Protein_Supply_Quantity_Data.csv"
Protein_Supply_Quantity_df = pd.read_csv(Protein_Supply_Quantity)

Protein_Supply_Quantity_df.head()
# Out:
#                Country  Alcoholic Beverages  Animal Products  Animal fats  \
# 0          Afghanistan               0.0000           9.7523       0.0277
# 1              Albania               0.1840          27.7469       0.0711
# 2              Algeria               0.0323          13.8360       0.0054
# 3               Angola               0.6285          15.2311       0.0277
# 4  Antigua and Barbuda               0.1535          33.1901       0.1289
#
#    Aquatic Products, Other  Cereals - Excluding Beer    Eggs  Fish, Seafood  \
# 0                      0.0                   35.9771  0.4067         0.0647
# 1                      0.0                   14.2331  1.8069         0.6274
# 2                      0.0                   26.5633  1.2916         0.6350
# 3                      0.0                   20.3882  0.1756         5.4436
# 4                      0.0                   10.5108  0.4850         8.2146
#
#    Fruits - Excluding Wine     Meat  ...  Vegetables  Miscellaneous  Obesity  \
# 0                   0.5824   3.1337  ...      1.1370         0.0462      4.5
# 1                   1.2757   7.6582  ...      3.2456         0.0544     22.3
# 2                   1.1624   3.5088  ...      3.1267         0.1399     26.6
# 3                   1.2754   7.6248  ...      0.8133         0.0924      6.8
# 4                   1.2586  16.0670  ...      1.6024         0.2947     19.1
#
#    Undernourished  Confirmed    Deaths  Recovered    Active  Population  \
# 0            29.8   0.142134  0.006186   0.123374  0.012574  38928000.0
# 1             6.2   2.967301  0.050951   1.792636  1.123714   2838000.0
# 2             3.9   0.244897  0.006558   0.167572  0.070767  44357000.0
# 3              25   0.061687  0.001461   0.056808  0.003419  32522000.0
# 4             NaN   0.293878  0.007143   0.190816  0.095918     98000.0
#
#    Unit (all except Population)
# 0                             %
# 1                             %
# 2                             %
# 3                             %
# 4                             %
#
# [5 rows x 32 columns]

# %% [markdown]
# # Create a filtered dataframe for each dataframe

# %%
#Create a filtered dataframe from specific columns
Food_Supply_Quantity_cols = ['Country', 'Animal Products', 'Cereals - Excluding Beer',
                             'Eggs', 'Fruits - Excluding Wine', 'Meat', 'Milk - Excluding Butter', 'Fish, Seafood', 'Vegetables']
Food_Supply_Quantity_transformed= Food_Supply_Quantity_df[Food_Supply_Quantity_cols].copy()

#Rename column headers 
Food_Supply_Quantity_transformed = Food_Supply_Quantity_transformed.rename(columns={'Country': 'country', 
                                                                                    'Animal Products':'animal_products',
                                                                                    'Cereals - Excluding Beer':'cereals',
                                                                                    'Eggs':'eggs',
                                                                                    'Fruits - Excluding Wine': 'fruits',
                                                                                    'Meat':'meat',
                                                                                    'Milk - Excluding Butter':'milk',
                                                                                    'Fish, Seafood': 'fish_seafood', 
                                                                                    'Vegetables':'vegetables'})


#Clean the data by dropping duplicates and setting the index
Food_Supply_Quantity_transformed.drop_duplicates("country", inplace=True)
Food_Supply_Quantity_transformed.set_index("country", inplace=True)

Food_Supply_Quantity_transformed.insert(0,'type', 2)

Food_Supply_Quantity_transformed
# Out:
#                                     type  animal_products  cereals    eggs  \
# country
# Afghanistan                            2           9.4341  24.8097  0.2099
# Albania                                2          18.7684   5.7817  0.5815
# Algeria                                2           9.6334  13.6816  0.5277
# Angola                                 2           4.9278   9.1085  0.0587
# Antigua and Barbuda                    2          16.6613   5.9960  0.2274
# ...                                  ...              ...      ...     ...
# Venezuela (Bolivarian Republic of)     2          14.7565  12.9253  0.3389
# Vietnam                                2           8.5765  16.8740  0.3077
# Yemen                                  2           5.7874  27.2077  0.2579
# Zambia                                 2           6.0197  21.1938  0.3399
# Zimbabwe                               2           8.1489  22.6240  0.2678
#
#                                      fruits    meat     milk  fish_seafood  \
# country
# Afghanistan                          5.3495  1.2020   7.5828        0.0350
# Albania                              6.7861  1.8845  15.7213        0.2126
# Algeria                              6.3801  1.1305   7.6189        0.2416
# Angola                               6.0005  2.0571   0.8311        1.7707
# Antigua and Barbuda                 10.7451  5.6888   6.3663        4.1489
# ...                                     ...     ...      ...           ...
# Venezuela (Bolivarian Republic of)   7.6460  3.8328   9.3920        0.9456
# Vietnam                              5.9029  4.4382   0.6069        2.6392
# Yemen                                5.1344  2.7871   1.8911        0.5240
# Zambia                               1.0183  1.8427   1.7570        1.6924
# Zimbabwe                             2.2000  2.6142   4.4310        0.5518
#
#                                     vegetables
# country
# Afghanistan                             6.7642
# Albania                                11.7753
# Algeria                                11.6484
# Angola                                  2.3041
# Antigua and Barbuda                     5.4495
# ...                                        ...
# Venezuela (Bolivarian Republic of)      4.1474
# Vietnam                                11.9508
# Yemen                                   3.2135
# Zambia                                  3.4649
# Zimbabwe                                2.3213
#
# [170 rows x 9 columns]

# %%
#Create a filtered dataframe from specific columns
Fat_Supply_Quantity_cols = ['Country', 'Animal Products', 'Cereals - Excluding Beer',
                             'Eggs', 'Fruits - Excluding Wine', 'Meat', 'Milk - Excluding Butter', 'Fish, Seafood', 'Vegetables']
Fat_Supply_Quantity_transformed= Fat_Supply_Quantity_df[Fat_Supply_Quantity_cols].copy()

#Rename column headers 
Fat_Supply_Quantity_transformed = Fat_Supply_Quantity_transformed.rename(columns={'Country': 'country', 
                                                                                    'Animal Products':'animal_products',
                                                                                    'Cereals - Excluding Beer':'cereals',
                                                                                    'Eggs':'eggs',
                                                                                    'Fruits - Excluding Wine': 'fruits',
                                                                                    'Meat':'meat',
                                                                                    'Milk - Excluding Butter':'milk',
                                                                                    'Fish, Seafood': 'fish_seafood', 
                                                                                    'Vegetables':'vegetables'})


#Clean the data by dropping duplicates and setting the index
Fat_Supply_Quantity_transformed.drop_duplicates("country", inplace=True)
Fat_Supply_Quantity_transformed.set_index("country", inplace=True)

Fat_Supply_Quantity_transformed.insert(0,'type', 1)

Fat_Supply_Quantity_transformed
# Out:
#                                     type  animal_products  cereals    eggs  \
# country
# Afghanistan                            1          21.6397   8.0353  0.6859
# Albania                                1          32.0002   2.6734  1.6448
# Algeria                                1          14.4175   4.2035  1.2171
# Angola                                 1          15.3041   6.5545  0.1539
# Antigua and Barbuda                    1          27.7033   3.2153  0.3872
# ...                                  ...              ...      ...     ...
# Venezuela (Bolivarian Republic of)     1          16.3261   2.5449  0.6555
# Vietnam                                1          33.2484   3.7155  0.7839
# Yemen                                  1          12.5401  11.5271  0.5514
# Zambia                                 1           9.6005  14.3225  0.6266
# Zimbabwe                               1          10.3796   9.7922  0.3682
#
#                                     fruits     meat     milk  fish_seafood  \
# country
# Afghanistan                         0.4246   6.1244   8.2803        0.0327
# Albania                             0.6418   8.7428  17.7576        0.1445
# Algeria                             0.5772   3.8961   8.0934        0.2008
# Angola                              0.3488  11.0268   1.2309        1.4155
# Antigua and Barbuda                 1.2177  14.3202   6.6607        1.5263
# ...                                    ...      ...      ...           ...
# Venezuela (Bolivarian Republic of)  0.9640   7.0949   5.5217        0.5707
# Vietnam                             0.4079  26.4292   0.7520        1.1217
# Yemen                               0.2564   8.0010   1.3463        0.3847
# Zambia                              0.1343   4.9010   1.2756        1.0070
# Zimbabwe                            0.0614   4.5674   2.1040        0.2455
#
#                                     vegetables
# country
# Afghanistan                             0.3593
# Albania                                 0.6503
# Algeria                                 0.5145
# Angola                                  0.1231
# Antigua and Barbuda                     0.2469
# ...                                        ...
# Venezuela (Bolivarian Republic of)      0.1851
# Vietnam                                 0.6373
# Yemen                                   0.1667
# Zambia                                  0.1567
# Zimbabwe                                0.0789
#
# [170 rows x 9 columns]

# %%
#Create a filtered dataframe from specific columns
Food_Supply_Kcal_cols = ['Country', 'Animal Products', 'Cereals - Excluding Beer',
                             'Eggs', 'Fruits - Excluding Wine', 'Meat', 'Milk - Excluding Butter', 'Fish, Seafood', 'Vegetables']
Food_Supply_Kcal_transformed= Food_Supply_Kcal_df[Food_Supply_Kcal_cols].copy()

#Rename column headers 
Food_Supply_Kcal_transformed = Food_Supply_Kcal_transformed.rename(columns={'Country': 'country', 
                                                                                    'Animal Products':'animal_products',
                                                                                    'Cereals - Excluding Beer':'cereals',
                                                                                    'Eggs':'eggs',
                                                                                    'Fruits - Excluding Wine': 'fruits',
                                                                                    'Meat':'meat',
                                                                                    'Milk - Excluding Butter':'milk',
                                                                                    'Fish, Seafood': 'fish_seafood', 
                                                                                    'Vegetables':'vegetables'})


#Clean the data by dropping duplicates and setting the index
Food_Supply_Kcal_transformed.drop_duplicates("country", inplace=True)
Food_Supply_Kcal_transformed.set_index("country", inplace=True)

Food_Supply_Kcal_transformed.insert(0,'type', 3)

Food_Supply_Kcal_transformed
# Out:
#                                     type  animal_products  cereals    eggs  \
# country
# Afghanistan                            3           4.7774  37.1186  0.1501
# Albania                                3          16.0930  16.2107  0.8091
# Algeria                                3           6.0326  25.0112  0.4181
# Angola                                 3           4.6927  18.3521  0.0441
# Antigua and Barbuda                    3          15.3672  13.7215  0.2057
# ...                                  ...              ...      ...     ...
# Venezuela (Bolivarian Republic of)     3           7.2303  21.3126  0.2892
# Vietnam                                3          10.9806  26.9833  0.2894
# Yemen                                  3           3.4667  32.0727  0.1455
# Zambia                                 3           3.3043  31.5528  0.1988
# Zimbabwe                               3           3.9356  29.8044  0.1381
#
#                                     fruits    meat    milk  fish_seafood  \
# country
# Afghanistan                         1.4757  1.2006  2.4512        0.0000
# Albania                             3.8982  3.8688  9.9441        0.1471
# Algeria                             3.1805  1.2543  3.9869        0.1195
# Angola                              2.3133  2.9302  0.5067        0.8372
# Antigua and Barbuda                 3.6824  7.0356  4.6904        1.7280
# ...                                    ...     ...     ...           ...
# Venezuela (Bolivarian Republic of)  2.3804  3.1368  2.6474        0.4449
# Vietnam                             1.8046  7.8311  0.5618        1.0385
# Yemen                               1.1879  2.0121  0.6545        0.1697
# Zambia                              0.2236  1.5155  0.5217        0.5714
# Zimbabwe                            0.4373  1.7491  1.0817        0.1611
#
#                                     vegetables
# country
# Afghanistan                             0.7504
# Albania                                 2.7508
# Algeria                                 2.0457
# Angola                                  0.3525
# Antigua and Barbuda                     1.2960
# ...                                        ...
# Venezuela (Bolivarian Republic of)      0.6674
# Vietnam                                 1.9578
# Yemen                                   0.3636
# Zambia                                  0.4472
# Zimbabwe                                0.2532
#
# [170 rows x 9 columns]

# %%
#Create a filtered dataframe from specific columns
Protein_Supply_Quantity_cols = ['Country', 'Animal Products', 'Cereals - Excluding Beer',
                             'Eggs', 'Fruits - Excluding Wine', 'Meat', 'Milk - Excluding Butter', 'Fish, Seafood', 'Vegetables']
Protein_Supply_Quantity_transformed= Protein_Supply_Quantity_df[Protein_Supply_Quantity_cols].copy()

#Rename column headers 
Protein_Supply_Quantity_transformed = Protein_Supply_Quantity_transformed.rename(columns={'Country': 'country', 
                                                                                    'Animal Products':'animal_products',
                                                                                    'Cereals - Excluding Beer':'cereals',
                                                                                    'Eggs':'eggs',
                                                                                    'Fruits - Excluding Wine': 'fruits',
                                                                                    'Meat':'meat',
                                                                                    'Milk - Excluding Butter':'milk',
                                                                                    'Fish, Seafood': 'fish_seafood', 
                                                                                    'Vegetables':'vegetables'})

#Clean the data by dropping duplicates and setting the index
Protein_Supply_Quantity_transformed.drop_duplicates("country", inplace=True)
Protein_Supply_Quantity_transformed.set_index("country", inplace=True)

Protein_Supply_Quantity_transformed.insert(0,'type', 4)

Protein_Supply_Quantity_transformed
# Out:
#                                     type  animal_products  cereals    eggs  \
# country
# Afghanistan                            4           9.7523  35.9771  0.4067
# Albania                                4          27.7469  14.2331  1.8069
# Algeria                                4          13.8360  26.5633  1.2916
# Angola                                 4          15.2311  20.3882  0.1756
# Antigua and Barbuda                    4          33.1901  10.5108  0.4850
# ...                                  ...              ...      ...     ...
# Venezuela (Bolivarian Republic of)     4          22.5411  21.6526  0.8707
# Vietnam                                4          20.4466  18.5247  0.7665
# Yemen                                  4          10.0122  35.1179  0.4320
# Zambia                                 4           9.8925  28.5182  0.5839
# Zimbabwe                               4          11.3443  33.1934  0.5077
#
#                                     fruits     meat     milk  fish_seafood  \
# country
# Afghanistan                         0.5824   3.1337   5.5278        0.0647
# Albania                             1.2757   7.6582  16.4750        0.6274
# Algeria                             1.1624   3.5088   8.0616        0.6350
# Angola                              1.2754   7.6248   1.1460        5.4436
# Antigua and Barbuda                 1.2586  16.0670   7.4349        8.2146
# ...                                    ...      ...      ...           ...
# Venezuela (Bolivarian Republic of)  1.0662  11.8347   6.3083        2.6477
# Vietnam                             0.7165  11.0426   1.0887        5.7435
# Yemen                               0.4884   5.9453   1.9630        0.9392
# Zambia                              0.0931   4.3158   1.0324        3.0126
# Zimbabwe                            0.2636   6.6582   2.4114        1.0837
#
#                                     vegetables
# country
# Afghanistan                             1.1370
# Albania                                 3.2456
# Algeria                                 3.1267
# Angola                                  0.8133
# Antigua and Barbuda                     1.6024
# ...                                        ...
# Venezuela (Bolivarian Republic of)      1.0129
# Vietnam                                 3.7216
# Yemen                                   0.5448
# Zambia                                  0.8039
# Zimbabwe                                0.5955
#
# [170 rows x 9 columns]

# %% [markdown]
# # Concatenate  dataframes together
# Create one larger dataframe with all values from Fat Supply, Food Supply, Kcal, and Protein Suppy.

# %%
dfs = [Fat_Supply_Quantity_transformed, Food_Supply_Quantity_transformed, Food_Supply_Kcal_transformed, Protein_Supply_Quantity_transformed]
nan_value = 0

Covid_19_Diet = pd.concat(dfs, join='outer').fillna(nan_value)

Covid_19_Diet
# Out:
#                                     type  animal_products  cereals    eggs  \
# country
# Afghanistan                            1          21.6397   8.0353  0.6859
# Albania                                1          32.0002   2.6734  1.6448
# Algeria                                1          14.4175   4.2035  1.2171
# Angola                                 1          15.3041   6.5545  0.1539
# Antigua and Barbuda                    1          27.7033   3.2153  0.3872
# ...                                  ...              ...      ...     ...
# Venezuela (Bolivarian Republic of)     4          22.5411  21.6526  0.8707
# Vietnam                                4          20.4466  18.5247  0.7665
# Yemen                                  4          10.0122  35.1179  0.4320
# Zambia                                 4           9.8925  28.5182  0.5839
# Zimbabwe                               4          11.3443  33.1934  0.5077
#
#                                     fruits     meat     milk  fish_seafood  \
# country
# Afghanistan                         0.4246   6.1244   8.2803        0.0327
# Albania                             0.6418   8.7428  17.7576        0.1445
# Algeria                             0.5772   3.8961   8.0934        0.2008
# Angola                              0.3488  11.0268   1.2309        1.4155
# Antigua and Barbuda                 1.2177  14.3202   6.6607        1.5263
# ...                                    ...      ...      ...           ...
# Venezuela (Bolivarian Republic of)  1.0662  11.8347   6.3083        2.6477
# Vietnam                             0.7165  11.0426   1.0887        5.7435
# Yemen                               0.4884   5.9453   1.9630        0.9392
# Zambia                              0.0931   4.3158   1.0324        3.0126
# Zimbabwe                            0.2636   6.6582   2.4114        1.0837
#
#                                     vegetables
# country
# Afghanistan                             0.3593
# Albania                                 0.6503
# Algeria                                 0.5145
# Angola                                  0.1231
# Antigua and Barbuda                     0.2469
# ...                                        ...
# Venezuela (Bolivarian Republic of)      1.0129
# Vietnam                                 3.7216
# Yemen                                   0.5448
# Zambia                                  0.8039
# Zimbabwe                                0.5955
#
# [680 rows x 9 columns]

# %%
connection_string = "postgres:Kemb@2010@localhost:5432/ETL_db"
engine = create_engine(f'postgresql://{connection_string}')

# %%
engine.table_names()
# Out:
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:1: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
#   """Entry point for launching an IPython kernel.
# ['fat_supply_quantity',
#  'food_supply_quantity',
#  'food_supply_kcal',
#  'protein_supply_quantity',
#  'covid_19_diet']

# %% [markdown]
# # Load DataFrames into database

# %%
Fat_Supply_Quantity_transformed.to_sql(name='fat_supply_quantity', con=engine, if_exists='append', index=True)

# %%
Food_Supply_Quantity_transformed.to_sql(name='food_supply_quantity', con=engine, if_exists='append', index=True)

# %%
Food_Supply_Kcal_transformed.to_sql(name='food_supply_kcal', con=engine, if_exists='append', index=True)

# %%
Protein_Supply_Quantity_transformed.to_sql(name='protein_supply_quantity', con=engine, if_exists='append', index=True)

# %%
Covid_19_Diet.to_sql(name='covid_19_diet', con=engine, if_exists='append', index=True)
